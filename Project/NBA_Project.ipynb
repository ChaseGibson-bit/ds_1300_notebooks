# %%
import pandas as pd

# %%
nba21 = pd.read_csv('../Project/2021_NBA_Data.csv', delimiter=",")
Adv21 = pd.read_csv('../Project/Adv_21.csv', delimiter=",")
nba21['CompScore'] = (((nba21['G']*0.5))+((nba21['DRB']+nba21['STL']+nba21['BLK'])/3)+Adv21['DWS']+Adv21['DBPM'])/6
DP21 = nba21.sort_values(by='CompScore',ascending=False)
DP21.head(5)
# Out:
#       Rk                    Player Pos  Age   Tm   G  GS    MP    FG   FGA  \
# 228  179     Rudy Gobert\goberru01   C   28  UTA  71  71  30.8   5.5   8.2
# 343  262    Nikola Jokić\jokicni01   C   25  DEN  72  72  34.6  10.2  18.0
# 544  421   Julius Randle\randlju01  PF   26  NYK  71  71  37.6   8.5  18.6
# 483  376   Royce O'Neale\onealro01  SF   27  UTA  71  71  31.6   2.5   5.5
# 655  504  Nikola Vučević\vucevni01   C   30  TOT  70  70  33.5   9.5  19.9
#
#      ...  ORB   DRB   TRB  AST  STL  BLK  TOV   PF   PTS  CompScore
# 228  ...  3.4  10.1  13.5  1.3  0.6  2.7  1.7  2.3  14.3   7.944444
# 343  ...  2.8   8.0  10.8  8.3  1.3  0.7  3.1  2.7  26.4   7.538889
# 544  ...  1.2   9.0  10.2  6.0  0.9  0.3  3.4  3.2  24.1   7.316667
# 483  ...  1.2   5.6   6.8  2.5  0.8  0.5  1.2  2.6   7.0   7.133333
# 655  ...  2.1   9.6  11.7  3.8  0.9  0.7  1.8  2.0  23.4   6.988889
#
# [5 rows x 31 columns]

# %%
nba20 = pd.read_csv('../Project/2020_NBA_Data.csv', delimiter=",")
Adv20 = pd.read_csv('../Project/Adv_20.csv', delimiter=",")
nba20['CompScore'] = (((nba20['G']*0.5))+((nba20['DRB']+nba20['STL']+nba20['BLK'])/3)+Adv20['DWS']+Adv20['DBPM'])/6
DP20 = nba20.sort_values(by='CompScore',ascending=False)
DP20.head(5)
# Out:
#       Rk                           Player Pos  Age   Tm   G  GS    MP    FG  \
# 1      2            Bam Adebayo\adebaba01  PF   22  MIA  72  72  33.6   6.1
# 12    13  Giannis Antetokounmpo\antetgi01  PF   25  MIL  63  63  30.4  10.9
# 334  261           Nikola Jokić\jokicni01   C   24  DEN  73  73  32.0   7.7
# 229  176            Rudy Gobert\goberru01   C   27  UTA  68  68  34.3   5.7
# 379  300            Brook Lopez\lopezbr01   C   31  MIL  68  67  26.7   4.3
#
#       FGA  ...  ORB   DRB   TRB  AST  STL  BLK  TOV   PF   PTS  CompScore
# 1    11.0  ...  2.4   7.8  10.2  5.1  1.1  1.3  2.8  2.5  15.9   7.550000
# 12   19.7  ...  2.2  11.4  13.6  5.6  1.0  1.0  3.7  3.1  29.5   7.511111
# 334  14.7  ...  2.3   7.5   9.7  7.0  1.2  0.6  3.1  3.0  19.9   7.450000
# 229   8.2  ...  3.4  10.1  13.5  1.5  0.8  2.0  1.9  3.2  15.1   7.400000
# 379   9.9  ...  0.9   3.7   4.6  1.5  0.7  2.4  1.0  2.4  12.0   7.144444
#
# [5 rows x 31 columns]

# %%
nba19 = pd.read_csv('../Project/2019_NBA_Data.csv', delimiter=",")
Adv19 = pd.read_csv('../Project/Adv_19.csv', delimiter=",")
nba19['CompScore'] = (((nba19['G']*0.5))+((nba19['DRB']+nba19['STL']+nba19['BLK'])/3)+Adv19['DWS']+Adv19['DBPM'])/6
DP19 = nba19.sort_values(by='CompScore',ascending=False)
DP19.head(5)
# Out:
#       Rk                           Player Pos  Age   Tm   G  GS    MP    FG  \
# 244  187            Rudy Gobert\goberru01   C   26  UTA  81  80  31.8   5.9
# 188  147         Andre Drummond\drumman01   C   25  DET  79  79  33.5   7.1
# 353  269           Nikola Jokić\jokicni01   C   23  DEN  80  80  31.3   7.7
# 662  493         Nikola Vučević\vucevni01   C   28  ORL  80  80  31.4   8.8
# 19    18  Giannis Antetokounmpo\antetgi01  PF   24  MIL  72  72  32.8  10.0
#
#       FGA  ...  ORB   DRB   TRB  AST  STL  BLK  TOV   PF   PTS  CompScore
# 244   8.8  ...  3.8   9.0  12.9  2.0  0.8  2.3  1.6  2.9  15.9   8.788889
# 188  13.3  ...  5.4  10.2  15.6  1.4  1.7  1.7  2.2  3.4  17.3   8.455556
# 353  15.1  ...  2.9   8.0  10.8  7.3  1.4  0.7  3.1  2.9  20.1   8.427778
# 662  16.9  ...  2.8   9.2  12.0  3.8  1.0  1.1  2.0  2.0  20.8   8.361111
# 19   17.3  ...  2.2  10.3  12.5  5.9  1.3  1.5  3.7  3.2  27.7   8.327778
#
# [5 rows x 31 columns]

# %%
nba18 = pd.read_csv('../Project/2018_NBA_Data.csv', delimiter=",")
Adv18 = pd.read_csv('../Project/Adv_18.csv', delimiter=",")
nba18['CompScore'] = (((nba18['G']*0.5))+((nba18['DRB']+nba18['STL']+nba18['BLK'])/3)+Adv18['DWS']+Adv18['DBPM'])/6
DP18 = nba18.sort_values(by='CompScore',ascending=False)
DP18.head(5)
# Out:
#       Rk                       Player Pos  Age   Tm   G  GS    MP    FG   FGA  \
# 168  140     Andre Drummond\drumman01   C   24  DET  78  78  33.7   6.0  11.3
# 555  451        Ben Simmons\simmobe01  PG   21  PHI  81  81  33.7   6.7  12.3
# 625  508  Russell Westbrook\westbru01  PG   29  OKC  80  80  36.4   9.5  21.1
# 303  248       LeBron James\jamesle01  PF   33  CLE  82  82  36.9  10.5  19.3
# 135  113   Robert Covington\covinro01  SF   27  PHI  80  80  31.7   4.3  10.5
#
#      ...  ORB   DRB   TRB   AST  STL  BLK  TOV   PF   PTS  CompScore
# 168  ...  5.1  10.9  16.0   3.0  1.5  1.6  2.6  3.2  15.0   8.511111
# 555  ...  1.8   6.3   8.1   8.2  1.7  0.9  3.4  2.6  15.8   8.494444
# 625  ...  1.9   8.2  10.1  10.3  1.8  0.3  4.8  2.5  25.4   8.238889
# 303  ...  1.2   7.5   8.6   9.1  1.4  0.9  4.2  1.7  27.5   8.111111
# 135  ...  0.7   4.7   5.4   2.0  1.7  0.9  1.6  3.0  12.6   8.105556
#
# [5 rows x 31 columns]

# %%
nba17 = pd.read_csv('../Project/2017_NBA_Data.csv', delimiter=",")
Adv17 = pd.read_csv('../Project/Adv_17.csv', delimiter=",")
nba17['CompScore'] = ((nba17['G']*0.5)+nba17['DRB']+nba17['STL']+nba17['BLK']+Adv17['DWS']+Adv17['DBPM'])/6
DP17 = nba17.sort_values(by='CompScore',ascending=False)
DP17.head(5)
# Out:
#       Rk                       Player Pos  Age   Tm   G  GS    MP    FG   FGA  \
# 189  155        Rudy Gobert\goberru01   C   24  UTA  81  81  33.9   5.1   7.7
# 137  115     Andre Drummond\drumman01   C   23  DET  81  81  29.7   6.0  11.2
# 558  458  Russell Westbrook\westbru01  PG   28  OKC  81  81  34.6  10.2  24.0
# 293  240     DeAndre Jordan\jordade01   C   28  LAC  81  81  31.7   5.1   7.1
# 561  461   Hassan Whiteside\whiteha01   C   27  MIA  77  77  32.6   7.0  12.6
#
#      ...  ORB   DRB   TRB   AST  STL  BLK  TOV   PF   PTS  CompScore
# 189  ...  3.9   8.9  12.8   1.2  0.6  2.6  1.8  3.0  14.0  10.133333
# 137  ...  4.3   9.5  13.8   1.1  1.5  1.1  1.9  2.9  13.6   9.783333
# 558  ...  1.7   9.0  10.7  10.4  1.6  0.4  5.4  2.3  31.6   9.750000
# 293  ...  3.7  10.1  13.8   1.2  0.6  1.7  1.4  2.6  12.7   9.733333
# 561  ...  3.8  10.3  14.1   0.7  0.7  2.1  2.0  2.9  17.0   9.566667
#
# [5 rows x 31 columns]

# %%
nba16 = pd.read_csv('../Project/2016_NBA_Data.csv', delimiter=",")
Adv16 = pd.read_csv('../Project/Adv_16.csv', delimiter=",")
nba16['CompScore'] = ((nba16['G']*0.5)+nba16['DRB']+nba16['STL']+nba16['BLK']+(Adv16['DWS']*0.75)+Adv16['DBPM'])/6
DP16 = nba16.sort_values(by='CompScore',ascending=False)
DP16.head(5)
# Out:
#       Rk                      Player Pos  Age   Tm   G  GS    MP   FG   FGA  \
# 188  166    Draymond Green\greendr01  PF   25  GSW  81  81  34.7  5.0  10.1
# 375  306      Paul Millsap\millspa01  PF   30  ATL  81  81  32.7  6.2  13.2
# 132  121    Andre Drummond\drumman01   C   22  DET  81  81  32.9  6.8  13.1
# 292  241    DeAndre Jordan\jordade01   C   27  LAC  77  77  33.7  4.6   6.6
# 554  453  Hassan Whiteside\whiteha01   C   26  MIA  73  43  29.1  5.7   9.3
#
#      ...  ORB   DRB   TRB  AST  STL  BLK  TOV   PF   PTS  CompScore
# 188  ...  1.7   7.8   9.5  7.4  1.5  1.4  3.2  3.0  14.0   9.654167
# 375  ...  2.4   6.6   9.0  3.3  1.8  1.7  2.4  2.9  17.1   9.633333
# 132  ...  4.9   9.9  14.8  0.8  1.5  1.4  1.9  3.0  16.2   9.620833
# 292  ...  3.5  10.3  13.8  1.2  0.7  2.3  1.4  2.7  12.7   9.537500
# 554  ...  3.3   8.6  11.8  0.4  0.6  3.7  1.9  2.8  14.2   9.295833
#
# [5 rows x 31 columns]

# %%
nba15 = pd.read_csv('../Project/2015_NBA_Data.csv', delimiter=",")
Adv15 = pd.read_csv('../Project/Adv_15.csv', delimiter=",")
nba15['CompScore'] = ((nba15['G']*0.5)+(nba15['DRB']*1.5)+(nba15['STL']*1.5)+(nba15['BLK']*1.5)+(Adv15['DWS']*0.5)+(Adv15['DBPM']*.5))/6
DP15 = nba15.sort_values(by='CompScore',ascending=False)
DP15.head(5)
# Out:
#       Rk                    Player Pos  Age   Tm   G  GS    MP   FG   FGA  \
# 315  254  DeAndre Jordan\jordade01   C   26  LAC  82  82  34.4  4.6   6.5
# 171  135  Andre Drummond\drumman01   C   21  DET  82  82  30.5  6.0  11.7
# 217  173     Rudy Gobert\goberru01   C   22  UTA  82  37  26.3  3.1   5.2
# 209  167       Pau Gasol\gasolpa01  PF   34  CHI  78  78  34.4  7.3  14.8
# 228  184  Draymond Green\greendr01  PF   24  GSW  79  79  31.5  4.3   9.7
#
#      ...  ORB   DRB   TRB  AST  STL  BLK  TOV   PF   PTS  CompScore
# 315  ...  4.8  10.1  15.0  0.7  1.0  2.2  1.3  3.0  11.5  10.666667
# 171  ...  5.3   8.1  13.5  0.7  0.9  1.9  1.5  3.5  13.8   9.858333
# 217  ...  3.2   6.2   9.5  1.3  0.8  2.3  1.4  2.1   8.4   9.725000
# 209  ...  2.8   9.0  11.8  2.7  0.3  1.9  2.0  1.9  18.5   9.716667
# 228  ...  1.4   6.7   8.2  3.7  1.6  1.3  1.7  3.2  11.7   9.650000
#
# [5 rows x 31 columns]

# %%
nba14 = pd.read_csv('../Project/2014_NBA_Data.csv', delimiter=",")
Adv14 = pd.read_csv('../Project/Adv_14.csv', delimiter=",")
nba14['CompScore'] = ((nba14['G']*0.5)+nba14['DRB']+nba14['STL']+nba14['BLK']+(Adv14['DWS']*0.75)+Adv14['DBPM'])/6
DP14 = nba14.sort_values(by='CompScore',ascending=False)
DP14.head(5)
# Out:
#       Rk                    Player Pos  Age   Tm   G  GS    MP    FG   FGA  \
# 319  246  DeAndre Jordan\jordade01   C   25  LAC  82  82  35.0   4.2   6.3
# 422  332      Joakim Noah\noahjo01   C   28  CHI  80  80  35.3   4.8  10.0
# 220  163     Paul George\georgpa01  SF   23  IND  80  80  36.2   7.2  17.0
# 185  134    Kevin Durant\duranke01  SF   25  OKC  81  81  38.5  10.5  20.8
# 285  216     Serge Ibaka\ibakase01  PF   24  OKC  81  81  32.9   6.5  12.1
#
#      ...  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS  CompScore
# 319  ...  4.0  9.5  13.6  0.9  1.0  2.5  1.5  3.2  10.4   9.991667
# 422  ...  3.5  7.7  11.3  5.4  1.2  1.5  2.4  3.1  12.6   9.825000
# 220  ...  0.8  6.0   6.8  3.5  1.9  0.3  2.8  2.5  21.7   9.183333
# 185  ...  0.7  6.7   7.4  5.5  1.3  0.7  3.5  2.1  32.0   8.983333
# 285  ...  2.8  6.0   8.8  1.0  0.5  2.7  1.5  2.9  15.1   8.933333
#
# [5 rows x 31 columns]

# %%
nba13 = pd.read_csv('../Project/2013_NBA_Data.csv', delimiter=",")
Adv13 = pd.read_csv('../Project/Adv_13.csv', delimiter=",")
nba13['CompScore'] = (((nba13['G']*0.5))+((nba13['DRB']+nba13['STL']+nba13['BLK'])/3)+Adv13['DWS']+Adv13['DBPM'])/6
DP13 = nba13.sort_values(by='CompScore',ascending=False)
DP13.head(5)
# Out:
#       Rk                  Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...  \
# 176  142    Marc Gasol\gasolma01   C   28  MEM  80  80  35.0  5.4  10.9  ...
# 183  147   Paul George\georgpa01  SF   22  IND  79  79  37.6  6.2  14.9  ...
# 148  120  Kevin Durant\duranke01  SF   24  OKC  81  81  38.5  9.0  17.7  ...
# 104   86   Mike Conley\conlemi01  PG   25  MEM  80  80  34.5  5.2  11.8  ...
# 227  185   Roy Hibbert\hibbero01   C   26  IND  79  79  28.7  4.9  10.9  ...
#
#      ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS  CompScore
# 176  2.3  5.5  7.8  4.0  1.0  1.7  2.0  3.2  14.1   8.538889
# 183  1.1  6.5  7.6  4.1  1.8  0.6  2.9  2.9  17.4   8.511111
# 148  0.6  7.3  7.9  4.6  1.4  1.3  3.5  1.8  28.1   8.472222
# 104  0.5  2.3  2.8  6.1  2.2  0.3  2.4  2.1  14.6   8.100000
# 227  3.7  4.6  8.3  1.4  0.5  2.6  2.1  3.5  11.9   8.061111
#
# [5 rows x 31 columns]

# %%
nba12 = pd.read_csv('../Project/2012_NBA_Data.csv', delimiter=",")
Adv12 = pd.read_csv('../Project/Adv_12.csv', delimiter=",")
nba12['CompScore'] = (((nba12['G']*0.5))+((nba12['DRB']+nba12['STL']+nba12['BLK'])/3)+Adv12['DWS']+Adv12['DBPM'])/6
DP12 = nba12.sort_values(by='CompScore',ascending=False)
DP12.head(5)
# Out:
#       Rk                   Player Pos  Age   Tm   G  GS    MP    FG   FGA  \
# 450  398     Josh Smith\smithjo03  PF   26  ATL  66  66  35.3   7.6  16.7
# 182  161     Marc Gasol\gasolma01   C   27  MEM  65  65  36.5   5.5  11.4
# 56    55  Carlos Boozer\boozeca01  PF   30  CHI  66  66  29.5   6.8  12.8
# 257  224    Serge Ibaka\ibakase01  PF   22  OKC  66  66  27.2   4.0   7.4
# 268  233   LeBron James\jamesle01  SF   27  MIA  62  62  37.5  10.0  18.9
#
#      ...  ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS  CompScore
# 450  ...  2.1  7.5  9.6  3.9  1.4  1.7  2.5  2.6  18.8   7.255556
# 182  ...  1.8  7.1  8.9  3.1  1.0  1.9  1.9  3.1  14.6   6.988889
# 56   ...  1.7  6.8  8.5  1.9  1.0  0.4  1.7  2.5  15.0   6.938889
# 257  ...  2.9  4.6  7.5  0.4  0.5  3.7  1.2  2.7   9.1   6.905556
# 268  ...  1.5  6.4  7.9  6.2  1.9  0.8  3.4  1.5  27.1   6.872222
#
# [5 rows x 31 columns]

# %%
nba11 = pd.read_csv('../Project/2011_NBA_Data.csv', delimiter=",")
Adv11 = pd.read_csv('../Project/Adv_11.csv', delimiter=",")
nba11['CompScore'] = (((nba11['G']*0.5))+((nba11['DRB']+nba11['STL']+nba11['BLK'])/3)+Adv11['DWS']+Adv11['DBPM'])/6
DP11 = nba11.sort_values(by='CompScore',ascending=False)
DP11.head(5)
# Out:
#       Rk                   Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...  \
# 294  211  Dwight Howard\howardw01   C   25  ORL  78  78  37.6  7.9  13.4  ...
# 230  160      Pau Gasol\gasolpa01   C   30  LAL  82  82  37.0  7.2  13.7  ...
# 311  226   LeBron James\jamesle01  SF   26  MIA  79  79  38.8  9.6  18.8  ...
# 89    62  Ronnie Brewer\brewero02  SG   25  CHI  81   1  22.0  2.5   5.3  ...
# 443  326      Chris Paul\paulch01  PG   25  NOH  80  80  36.0  5.4  11.6  ...
#
#      ORB   DRB   TRB  AST  STL  BLK  TOV   PF   PTS  CompScore
# 294  4.0  10.1  14.1  1.4  1.4  2.4  3.6  3.3  22.9   8.955556
# 230  3.3   6.9  10.2  3.3  0.6  1.6  1.7  2.5  18.8   8.272222
# 311  1.0   6.5   7.5  7.0  1.6  0.6  3.6  2.1  26.7   8.250000
# 89   0.7   2.6   3.2  1.7  1.3  0.3  0.7  1.0   6.2   8.233333
# 443  0.5   3.6   4.1  9.8  2.4  0.1  2.2  2.5  15.9   8.205556
#
# [5 rows x 31 columns]

# %%
nba10 = pd.read_csv('../Project/2010_NBA_Data.csv', delimiter=",")
Adv10 = pd.read_csv('../Project/Adv_10.csv', delimiter=",")
nba10['CompScore'] = (((nba10['G']*0.5))+((nba10['DRB']+nba10['STL']+nba10['BLK'])/3)+Adv10['DWS']+Adv10['DBPM'])/6
DP10= nba10.sort_values(by='CompScore',ascending=False)
DP10.head(5)
# Out:
#       Rk                    Player Pos  Age   Tm   G  GS    MP   FG   FGA  \
# 245  201   Dwight Howard\howardw01   C   24  ORL  82  82  34.7  6.2  10.2
# 487  371      Josh Smith\smithjo03  PF   24  ATL  81  81  35.4  6.2  12.3
# 413  315       Lamar Odom\odomla01  PF   30  LAL  82  38  31.5  4.2   9.0
# 149  125    Kevin Durant\duranke01  SF   21  OKC  82  82  39.5  9.7  20.3
# 541  408  Gerald Wallace\wallage01  SF   27  CHA  76  76  41.0  6.0  12.4
#
#      ...  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS  CompScore
# 245  ...  3.5  9.7  13.2  1.8  0.9  2.8  3.3  3.5  18.3   9.227778
# 487  ...  2.8  6.0   8.7  4.2  1.6  2.1  2.4  3.0  15.7   8.588889
# 413  ...  2.2  7.5   9.8  3.3  0.9  0.7  1.8  2.8  10.8   8.455556
# 149  ...  1.3  6.3   7.6  2.8  1.4  1.0  3.3  2.1  30.1   8.283333
# 541  ...  2.0  8.1  10.0  2.1  1.5  1.1  2.3  2.6  18.2   8.244444
#
# [5 rows x 31 columns]

# %%
nba09 = pd.read_csv('../Project/2009_NBA_Data.csv', delimiter=",")
Adv09 = pd.read_csv('../Project/Adv_09.csv', delimiter=",")
nba09['CompScore'] = (((nba09['G']*0.5))+((nba09['DRB']+nba09['STL']+nba09['BLK'])/3)+Adv09['DWS']+Adv09['DBPM'])/6
DP09 = nba09.sort_values(by='CompScore',ascending=False)
DP09.head(5)
# Out:
#       Rk                      Player Pos  Age   Tm   G  GS    MP   FG   FGA  \
# 249  191     Dwight Howard\howardw01   C   23  ORL  79  79  35.7  7.1  12.4
# 272  208      LeBron James\jamesle01  SF   24  CLE  81  81  37.7  9.7  19.9
# 413  317         Chris Paul\paulch01  PG   23  NOH  78  78  38.5  8.1  16.1
# 453  347       Rajon Rondo\rondora01  PG   22  BOS  80  80  33.0  4.8   9.5
# 533  401  Anderson Varejão\varejan01  PF   26  CLE  81  42  28.5  3.3   6.2
#
#      ...  ORB  DRB   TRB   AST  STL  BLK  TOV   PF   PTS  CompScore
# 249  ...  4.3  9.6  13.8   1.4  1.0  2.9  3.0  3.4  20.6   9.000000
# 272  ...  1.3  6.3   7.6   7.2  1.7  1.1  3.0  1.7  28.4   8.955556
# 413  ...  0.9  4.7   5.5  11.0  2.8  0.1  3.0  2.7  22.8   8.388889
# 453  ...  1.3  4.0   5.2   8.2  1.9  0.1  2.6  2.4  11.9   8.200000
# 533  ...  2.0  5.1   7.2   1.0  0.9  0.8  1.0  3.0   8.6   8.177778
#
# [5 rows x 31 columns]

# %%
nba08 = pd.read_csv('../Project/2008_NBA_Data.csv', delimiter=",")
Adv08 = pd.read_csv('../Project/Adv_08.csv', delimiter=",")
nba08['CompScore'] = (((nba08['G']*0.5))+((nba08['DRB']+nba08['STL']+nba08['BLK'])/3)+Adv08['DWS']+Adv08['DBPM'])/6
DP08 = nba08.sort_values(by='CompScore',ascending=False)
DP08.head(5)
# Out:
#       Rk                   Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...  \
# 88    72   Marcus Camby\cambyma01   C   33  DEN  79  79  34.9  3.6   8.0  ...
# 249  192  Dwight Howard\howardw01   C   22  ORL  82  82  37.7  7.1  11.9  ...
# 484  374     Josh Smith\smithjo03  PF   22  ATL  81  81  35.5  6.4  14.0  ...
# 146  118    Tim Duncan*\duncati01   C   31  SAS  78  78  34.0  7.5  15.1  ...
# 421  320      Chris Paul\paulch01  PG   22  NOH  80  80  37.6  7.9  16.1  ...
#
#      ORB   DRB   TRB   AST  STL  BLK  TOV   PF   PTS  CompScore
# 88   2.9  10.2  13.1   3.3  1.1  3.6  1.5  2.7   9.1   8.944444
# 249  3.4  10.8  14.2   1.3  0.9  2.1  3.2  3.3  20.7   8.866667
# 484  2.0   6.2   8.2   3.4  1.5  2.8  3.0  3.3  17.2   8.516667
# 146  3.0   8.3  11.3   2.8  0.7  1.9  2.3  2.4  19.3   8.505556
# 421  0.8   3.2   4.0  11.6  2.7  0.1  2.5  2.3  21.1   8.300000
#
# [5 rows x 31 columns]

# %%
nba07 = pd.read_csv('../Project/2007_NBA_Data.csv', delimiter=",")
Adv07 = pd.read_csv('../Project/Adv_07.csv', delimiter=",")
nba07['CompScore'] = (((nba07['G']*0.5))+((nba07['DRB']+nba07['STL']+nba07['BLK'])/3)+Adv07['DWS']+Adv07['DBPM'])/6
DP07 = nba07.sort_values(by='CompScore',ascending=False)
DP07.head(5)
# Out:
#       Rk                   Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...  \
# 125  114    Tim Duncan*\duncati01   C   30  SAS  80  80  34.1  7.7  14.1  ...
# 476  423   Ben Wallace*\wallabe01   C   32  CHI  77  77  35.0  2.5   5.5  ...
# 207  186  Dwight Howard\howardw01   C   21  ORL  82  82  36.9  6.4  10.6  ...
# 290  255   Shawn Marion\mariosh01  SF   28  PHO  80  80  37.6  7.0  13.4  ...
# 109  102       Luol Deng\denglu01  SF   21  CHI  82  82  37.5  7.7  14.9  ...
#
#      ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS  CompScore
# 125  2.7  7.9  10.6  3.4  0.8  2.4  2.8  2.5  20.0   8.950000
# 476  3.9  6.7  10.7  2.4  1.4  2.0  1.3  2.0   6.4   8.627778
# 207  3.5  8.8  12.3  1.9  0.9  1.9  3.9  3.0  17.6   8.627778
# 290  2.2  7.7   9.8  1.7  2.0  1.5  1.4  2.7  17.5   8.488889
# 109  1.8  5.3   7.1  2.5  1.2  0.6  1.9  2.0  18.8   8.377778
#
# [5 rows x 31 columns]

# %%
nba06 = pd.read_csv('../Project/2006_NBA_Data.csv', delimiter=",")
Adv06 = pd.read_csv('../Project/Adv_06.csv', delimiter=",")
nba06['CompScore'] = (((nba06['G']*0.5))+((nba06['DRB']+nba06['STL']+nba06['BLK'])/3)+Adv06['DWS']+Adv06['DBPM'])/6
DP06 = nba06.sort_values(by='CompScore',ascending=False)
DP06.head(5)
# Out:
#       Rk                    Player Pos  Age   Tm   G  GS    MP   FG   FGA  \
# 518  424    Ben Wallace*\wallabe01   C   31  DET  82  82  35.2  2.9   5.7
# 144  112     Tim Duncan*\duncati01  PF   29  SAS  80  80  34.8  7.2  14.8
# 309  254    Shawn Marion\mariosh01  PF   27  PHO  81  81  40.3  8.8  16.9
# 283  232      Jason Kidd*\kiddja01  PG   32  NJN  80  80  37.2  4.6  11.3
# 181  141  Kevin Garnett*\garneke01  PF   29  MIN  76  76  38.9  8.2  15.7
#
#      ...  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS  CompScore
# 518  ...  3.7  7.6  11.3  1.9  1.8  2.2  1.1  2.0   7.3   9.144444
# 144  ...  2.9  8.1  11.0  3.2  0.9  2.0  2.5  2.7  18.6   8.861111
# 309  ...  3.1  8.8  11.8  1.8  2.0  1.7  1.5  2.8  21.8   8.644444
# 283  ...  1.1  6.2   7.3  8.4  1.9  0.4  2.4  2.0  13.3   8.505556
# 181  ...  2.8  9.9  12.7  4.1  1.4  1.4  2.4  2.7  21.8   8.388889
#
# [5 rows x 31 columns]

# %%
nba05= pd.read_csv('../Project/2005_NBA_Data.csv', delimiter=",")
Adv05 = pd.read_csv('../Project/Adv_05.csv', delimiter=",")
nba05['CompScore'] = (((nba05['G']*0.5))+((nba05['DRB']+nba05['STL']+nba05['BLK'])/3)+Adv05['DWS']+Adv05['DBPM'])/6
DP05 = nba05.sort_values(by='CompScore',ascending=False)
DP05.head(5)
# Out:
#       Rk                    Player Pos  Age   Tm   G  GS    MP   FG   FGA  \
# 190  148  Kevin Garnett*\garneke01  PF   28  MIN  82  82  38.1  8.3  16.6
# 107   79  Tyson Chandler\chandty01   C   22  CHI  80  10  27.4  2.6   5.2
# 322  263    Shawn Marion\mariosh01  PF   26  PHO  81  81  38.8  7.6  15.9
# 538  432    Ben Wallace*\wallabe01   C   30  DET  74  74  36.1  4.0   8.8
# 384  308   Dirk Nowitzki\nowitdi01  PF   26  DAL  78  78  38.7  8.5  18.5
#
#      ...  ORB   DRB   TRB  AST  STL  BLK  TOV   PF   PTS  CompScore
# 190  ...  3.0  10.5  13.5  5.7  1.5  1.4  2.7  2.5  22.2   9.077778
# 107  ...  3.3   6.4   9.7  0.8  0.9  1.8  1.5  3.4   8.0   8.538889
# 322  ...  2.9   8.4  11.3  1.9  2.0  1.5  1.5  2.5  19.4   8.494444
# 538  ...  3.9   8.2  12.2  1.7  1.4  2.4  1.1  2.1   9.7   8.366667
# 384  ...  1.2   8.5   9.7  3.1  1.2  1.5  2.3  2.8  26.1   8.238889
#
# [5 rows x 31 columns]

# %%
nba04 = pd.read_csv('../Project/2004_NBA_Data.csv', delimiter=",")
Adv04 = pd.read_csv('../Project/Adv_04.csv', delimiter=",")
nba04['CompScore'] = (((nba04['G']*0.5))+((nba04['DRB']+nba04['STL']+nba04['BLK'])/3)+Adv04['DWS']+Adv04['DBPM'])/6
DP04 = nba04.sort_values(by='CompScore',ascending=False)
DP04.head(5)
# Out:
#       Rk                      Player Pos  Age   Tm   G  GS    MP   FG   FGA  \
# 530  409      Ben Wallace*\wallabe01   C   29  DET  81  81  37.7  3.9   9.2
# 184  143    Kevin Garnett*\garneke01  PF   27  MIN  82  82  39.4  9.8  19.6
# 434  337      Theo Ratliff\ratlith01   C   30  TOT  85  83  31.3  3.1   6.5
# 377  292  Rasho Nesterović\nestera01   C   27  SAS  82  82  28.7  4.0   8.5
# 315  251  Donyell Marshall\marshdo01  PF   30  TOT  82  74  36.4  5.7  12.4
#
#      ...  ORB   DRB   TRB  AST  STL  BLK  TOV   PF   PTS  CompScore
# 530  ...  4.0   8.4  12.4  1.7  1.8  3.0  1.5  2.0   9.5   9.550000
# 184  ...  3.0  10.9  13.9  5.0  1.5  2.2  2.6  2.5  24.2   9.527778
# 434  ...  2.3   4.9   7.2  0.8  0.6  3.6  1.4  3.5   7.9   8.538889
# 377  ...  3.1   4.6   7.7  1.4  0.6  2.0  1.3  3.0   8.7   8.533333
# 315  ...  2.6   7.3   9.9  1.5  1.1  1.5  1.4  3.0  14.7   8.433333
#
# [5 rows x 31 columns]

# %%
nba03 = pd.read_csv('../Project/2003_NBA_Data.csv', delimiter=",")
Adv03 = pd.read_csv('../Project/Adv_03.csv', delimiter=",")
nba03['CompScore'] = (((nba03['G']*0.5))+((nba03['DRB']+nba03['STL']+nba03['BLK'])/3)+Adv03['DWS']+Adv03['DBPM'])/6
DP03 = nba03.sort_values(by='CompScore',ascending=False)
DP03.head(5)
# Out:
#       Rk                    Player Pos  Age   Tm   G  GS    MP   FG   FGA  \
# 123  109     Tim Duncan*\duncati01  PF   26  SAS  81  81  39.3  8.8  17.2
# 145  131  Kevin Garnett*\garneke01  PF   26  MIN  82  82  40.5  9.1  18.1
# 441  393    Ben Wallace*\wallabe01   C   28  DET  73  73  39.4  2.9   6.0
# 265  235    Shawn Marion\mariosh01  SF   24  PHO  81  81  41.6  8.2  18.1
# 316  278   Dirk Nowitzki\nowitdi01  PF   24  DAL  80  80  39.0  8.6  18.6
#
#      ...  ORB   DRB   TRB  AST  STL  BLK  TOV   PF   PTS  CompScore
# 123  ...  3.2   9.7  12.9  3.9  0.7  2.9  3.1  2.9  23.3   9.055556
# 145  ...  3.0  10.5  13.4  6.0  1.4  1.6  2.8  2.4  23.0   8.950000
# 441  ...  4.0  11.4  15.4  1.6  1.4  3.2  1.2  2.5   6.9   8.872222
# 265  ...  2.5   7.1   9.5  2.4  2.3  1.2  1.9  2.6  21.2   8.605556
# 316  ...  1.0   8.9   9.9  3.0  1.4  1.0  1.9  2.6  25.1   8.411111
#
# [5 rows x 31 columns]

# %%
nba02 = pd.read_csv('../Project/2002_NBA_Data.csv', delimiter=",")
Adv02 = pd.read_csv('../Project/Adv_02.csv', delimiter=",")
nba02['CompScore'] = (((nba02['G']*0.5))+((nba02['DRB']+nba02['STL']+nba02['BLK'])/3)+Adv02['DWS']+Adv02['DBPM'])/6
DP02 = nba02.sort_values(by='CompScore',ascending=False)
DP02.head(5)
# Out:
#       Rk                    Player Pos  Age   Tm   G  GS    MP   FG   FGA  \
# 470  413    Ben Wallace*\wallabe01   C   27  DET  80  80  36.5  3.2   6.0
# 138  121     Tim Duncan*\duncati01  PF   25  SAS  82  82  40.6  9.3  18.3
# 161  144  Kevin Garnett*\garneke01  PF   25  MIN  81  81  39.2  8.1  17.3
# 249  218      Jason Kidd*\kiddja01  PG   28  NJN  82  82  37.3  5.4  13.9
# 366  323    Paul Pierce*\piercpa01  SG   24  BOS  82  82  40.3  8.6  19.5
#
#      ...  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS  CompScore
# 470  ...  4.0  9.0  13.0  1.4  1.7  3.5  0.9  2.2   7.6   9.205556
# 138  ...  3.3  9.4  12.7  3.7  0.7  2.5  3.2  2.6  25.5   9.083333
# 161  ...  3.0  9.1  12.1  5.2  1.2  1.6  2.8  2.3  21.2   8.527778
# 249  ...  1.6  5.7   7.3  9.9  2.1  0.2  3.5  1.7  14.7   8.494444
# 366  ...  1.0  5.9   6.9  3.2  1.9  1.0  2.9  2.9  26.1   8.472222
#
# [5 rows x 31 columns]

# %%
nba01 = pd.read_csv('../Project/2001_NBA_Data.csv', delimiter=",")
Adv01 = pd.read_csv('../Project/Adv_01.csv', delimiter=",")
nba01['CompScore'] = (((nba01['G']*0.5))+((nba01['DRB']+nba01['STL']+nba01['BLK'])/3)+Adv01['DWS']+Adv01['DBPM'])/6
DP01 = nba01.sort_values(by='CompScore',ascending=False)
DP01.head(5)
# Out:
#       Rk                     Player Pos  Age   Tm   G  GS    MP   FG   FGA  \
# 136  111      Tim Duncan*\duncati01  PF   24  SAS  82  82  38.7  8.6  17.1
# 504  415     Ben Wallace*\wallabe01   C   26  DET  80  80  34.5  2.7   5.5
# 423  346  David Robinson*\robinda01   C   35  SAS  80  80  29.6  5.0  10.3
# 289  240     Shawn Marion\mariosh01  SF   22  PHO  79  79  36.2  7.1  14.7
# 167  138   Kevin Garnett*\garneke01  PF   24  MIN  81  81  39.5  8.7  18.2
#
#      ...  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS  CompScore
# 136  ...  3.2  9.0  12.2  3.0  0.9  2.3  3.0  3.0  22.2   8.994444
# 504  ...  3.8  9.4  13.2  1.5  1.3  2.3  1.5  2.4   6.4   8.805556
# 423  ...  2.6  6.0   8.6  1.5  1.0  2.5  1.5  2.7  14.4   8.594444
# 289  ...  2.8  7.9  10.7  2.0  1.7  1.4  1.6  2.7  17.3   8.561111
# 167  ...  2.7  8.7  11.4  5.0  1.4  1.8  2.8  2.5  22.0   8.444444
#
# [5 rows x 31 columns]

# %%
nba00 = pd.read_csv('../Project/2000_NBA_Data.csv', delimiter=",")
Adv00 = pd.read_csv('../Project/Adv_00.csv', delimiter=",")
nba00['CompScore'] = (((nba00['G']*0.5))+((nba00['DRB']+nba00['STL']+nba00['BLK'])/3)+Adv00['DWS']+Adv00['DBPM'])/6
DP00 = nba00.sort_values(by='CompScore',ascending=False)
DP00.head(5)
# Out:
#       Rk                       Player Pos  Age   Tm   G  GS    MP    FG   FGA  \
# 336  294  Shaquille O'Neal*\onealsh01   C   27  LAL  79  79  40.0  12.1  21.1
# 389  343    David Robinson*\robinda01   C   34  SAS  80  80  32.0   6.6  12.9
# 162  140     Kevin Garnett*\garneke01  PF   23  MIN  81  81  40.0   9.4  18.8
# 328  286   Dikembe Mutombo*\mutomdi01   C   33  ATL  82  82  36.4   3.9   7.0
# 343  301          Bo Outlaw\outlabo01  PF   28  ORL  82  55  28.4   2.5   4.1
#
#      ...  ORB   DRB   TRB  AST  STL  BLK  TOV   PF   PTS  CompScore
# 336  ...  4.3   9.4  13.6  3.8  0.5  3.0  2.8  3.2  29.7   8.800000
# 389  ...  2.4   7.2   9.6  1.8  1.2  2.3  2.1  3.1  17.8   8.794444
# 162  ...  2.8   9.0  11.8  5.0  1.5  1.6  3.3  2.5  22.9   8.638889
# 328  ...  3.7  10.4  14.1  1.3  0.3  3.3  2.1  3.0  11.5   8.577778
# 343  ...  2.5   3.9   6.4  3.0  1.4  1.8  1.6  2.5   6.0   8.494444
#
# [5 rows x 31 columns]

# %%
import glob
import pandas as pd

files = glob.glob('*.csv')

combined=pd.DataFrame()

for f in files:
    ff = pd.read_csv(f)
    ff['FileName'] = f
    combined=combined.append(ff)
combined = combined.reset_index(drop=True)

combined
# Out:
#           Rk                       Player Pos   Age   Tm     G    GS    MP  \
# 0        1.0       Álex Abrines\abrinal01  SG  23.0  OKC  68.0   6.0  15.5
# 1        2.0           Quincy Acy\acyqu01  PF  26.0  TOT  38.0   1.0  14.7
# 2        2.0           Quincy Acy\acyqu01  PF  26.0  DAL   6.0   0.0   8.0
# 3        2.0           Quincy Acy\acyqu01  PF  26.0  BRK  32.0   1.0  15.9
# 4        3.0       Steven Adams\adamsst01   C  23.0  OKC  80.0  80.0  29.9
# ...      ...                          ...  ..   ...  ...   ...   ...   ...
# 12470  437.0      David Wingate\wingada01  SG  37.0  SEA   1.0   0.0   9.0
# 12471  438.0   Rubén Wolkowyski\wolkoru01  PF  27.0  SEA  34.0   1.0   9.0
# 12472  439.0  Metta World Peace\artesro01  SF  21.0  CHI  76.0  74.0  31.1
# 12473  440.0    Lorenzen Wright\wrighlo02   C  25.0  ATL  71.0  46.0  28.0
# 12474  441.0        Wang Zhizhi\zhizhwa01   C  23.0  DAL   5.0   0.0   7.6
#
# ...

# %%
append.drop(columns=["name"])

# %%
merged = pd.merge(df,dates, left_on="Books", right_on="Name", how = 'inner').drop(columns=['Name'])
merged

# %%
#Changing Player Name/Adding UID (Separating the Player column)
R20['UID'] = R20['Player'].apply(lambda x: x.split('\\')[1])
R20
#Changing Player Name/Adding UID (Separating the Player column)
R20['UID'] = R20['Player'].apply(lambda x: x.split('\\')[1])
R20

#Changing Player Name/Adding UID (Separating the Player column)
R20['UID'] = R20['Player'].apply(lambda x: x.split('\\')[1])
R20

Radv20 = pd.merge(R20,Adv20, left_on="UID", right_on="UID", how = 'inner')
Radv20

# %%
R19 = rookie19.sort_values(by='PerGameCompScore',ascending=False)

# %%
plt.savefig('hall.pdf', bbox_inches='tight')

# %%
import pandas as pd
import matplotlib as plt

# %matplotlib inline
# %config InlineBackend.figure_format ='retina'

# %%
ax = DP19.head(5).plot.scatter(x='CompScore', y="Player")
plt = DP19.head(5).plot.scatter(x='CompScore', y='Player', color = 'red', label="Composite Score per Player", ax=ax, xlabel="Composite Score", ylabel="Player", title='NBA 2019 DPOY Prediction')

# %%
ax = DP21.head(5).plot.scatter(x='CompScore', y="Player")
plt = DP21.head(5).plot.scatter(x='CompScore', y='Player', color = 'green', label="Composite Score per Player", ax=ax, xlabel="Composite Score", ylabel="Player", title='NBA 2021 DPOY Prediction')

# %%
x = DP20.head(5).plot.scatter(x='CompScore', y="Player")
plt = DP20.head(5).plot.scatter(x='CompScore', y='Player', color = 'green', label="Composite Score per Player", ax=ax, xlabel="Composite Score", ylabel="Player", title='NBA 2020 DPOY Prediction')

# %%
x = DP19.head(5).plot.scatter(x='CompScore', y="Player")
plt = DP19.head(5).plot.scatter(x='CompScore', y='Player', color = 'green', label="Composite Score per Player", ax=ax, xlabel="Composite Score", ylabel="Player", title='NBA 2019 DPOY Prediction')

# %%
import matplotlib as plt
# %matplotlib inline
# %config InlineBackend.figure_format ='retina'
DP21['Name'] = DP21['Player'].apply(lambda x: x.split('\\')[1])
Sub = DP21[(DP21['CompScore']>=100)]
NBAplot = Sub[['Name','CompScore']]
nplot = NBAplot.plot(kind='bar',figsize=(15,7), color=('red'), xlabel="Defensive Player Name", ylabel="Composite Score", title='Composite Scores of 2021 Top NBA Defensive Players')
ha = ['right', 'center', 'left']
nplot.set_xticklabels(nplot.get_xticks(), rotation = 45, ha=ha[0])
nplot.set_xticklabels(Sub['Name'])
nplot;
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-29-da3ddc3e2d47> in <module>
#       5 Sub = DP21[(DP21['CompScore']>=100)]
#       6 NBAplot = Sub[['Name','CompScore']]
# ----> 7 nplot = NBAplot.plot(kind='bar',figsize=(15,7), color=('red'), xlabel="Defensive Player Name", ylabel="Composite Score", title='Composite Scores of 2021 Top NBA Defensive Players')
#       8 ha = ['right', 'center', 'left']
#       9 nplot.set_xticklabels(nplot.get_xticks(), rotation = 45, ha=ha[0])
#
# ~/.conda/envs/ds_1300/lib/python3.9/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     953                     data.columns = label_name
#     954
# --> 955         return plot_backend.plot(data, kind=kind, **kwargs)
#     956
#     957     __call__.__doc__ = __doc__
#
# ...
