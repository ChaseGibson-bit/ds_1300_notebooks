# %% [markdown]
# # Working with Data

# %% [markdown]
# >Using the data below, answer the following questions:
#
# >1) Which entities (top 5) had the largest population density in 2020? (Sort and use .head)
# >2) Which entities have more water area than land area?
# >3) Which entities increased in population the most in the last 10 years?
# >4) What state bird accounts for the largest population as of 2020? Land area?
# >5) How many entities' largest city is their capital city?
# >6) Which entity has the largest percent drop from their largest city to their 5th largest? 100*(1st largest - 5th largest)/(1st largest)

# %%
#Question 1) District of Columbia, New Jersey, Rhode Island, Puerto Rico, Massachusetts

# %%
import pandas as pd

# %%
facts = pd.read_csv('../data/state_facts.tsv',delimiter="\t")
facts.head(5)
# Out:
#               State  Area_tot  Area_land  Area_water   Pop_2020  Pop_2010  \
# 0          Alabama     135767     131171        4597  5024279.0   4779736
# 1           Alaska    1723337    1477953      245384   733391.0    710231
# 2   American Samoa       1505        198        1307    49437.0     55519
# 3          Arizona     295234     294207        1026  7151502.0   6392017
# 4         Arkansas     137732     134771        2961  3011524.0   2915918
#
#   Rep_seats                        State_bird             State_flower  \
# 0         7  Yellowhammer (Northern flicker)                  Camellia
# 1         1                 Willow ptarmigan            Forget-me-not
# 2       1*                               None         Paogo (Ulafala)
# 3         9                      Cactus wren   Saguaro cactus blossom
# 4         4             Northern mockingbird            Apple blossom
#
#                       State_motto  ...        City_1 city_1_pop       City_2  \
# 0  Audemus jura nostra defendere   ...   Birmingham      208928  Huntsville
# 1            North to the Future   ...    Anchorage      291538      Juneau
# 2          Samoa, Muamua Le Atua   ...       Tafuna        7945     Nu'uuli
# 3                     Ditat Deus   ...      Phoenix     1660272      Tucson
# 4                 Regnat populus   ...  Little Rock      197881  Fort Smith
#
#    city_2_pop         City_3  city_3_pop       City_4  city_4_pop  \
# 0    204189.0    Montgomery     198956.0      Mobile     189572.0
# 1     32197.0     Fairbanks      31516.0     Wasilla      10529.0
# 2      3955.0     Pago Pago       3656.0    'Ili'ili       3195.0
# 3    545975.0          Mesa     508958.0    Chandler     257165.0
# 4     87845.0  Fayetteville      86751.0  Springdale      81029.0
#
#         City_5  city_5_pop
# 0  Tuscaloosa     101113.0
# 1       Sitka       8647.0
# 2   Pava'ia'i       2450.0
# 3  Scottsdale     255310.0
# 4   Jonesboro      76990.0
#
# [5 rows x 26 columns]

# %%
facts['PopDensity2020'] = facts['Pop_2020']/facts['Area_land']

# %%
PopDensity2020 = facts.sort_values(by='PopDensity2020',ascending=False)

# %%
PopDensity2020.head(5)
# Out:
#                      State  Area_tot  Area_land  Area_water   Pop_2020  \
# 9    District of Columbia        177        158          19   689545.0
# 32             New Jersey      22591      19047        3544  9288994.0
# 43           Rhode Island       4001       2678        1324  1097379.0
# 42            Puerto Rico      13791       8868        4924  3285874.0
# 23          Massachusetts      27336      20202        7134  7029917.0
#
#     Pop_2010 Rep_seats                               State_bird  \
# 9     601723       1*                              Wood thrush
# 32   8791894        12  Eastern goldfinch (American goldfinch)
# 43   1052567         2                        Rhode Island Red
# 42   3725789       1*                                     None
# 23   6547629         9                  Black-capped chickadee
#
#              State_flower                                 State_motto  ...  \
# 9   American Beauty Rose                            Justitia Omnibus   ...
# 32                Violet                      Liberty and Prosperity   ...
# 43                Violet                                        Hope   ...
# 42          Flor de Maga                      Joannes Est Nomen Eius   ...
# 23             Mayflower   Ense petit placidam sub libertate quietem   ...
#
#           City_2 city_2_pop        City_3  city_3_pop      City_4  city_4_pop  \
# 9            NaN        NaN           NaN         NaN         NaN         NaN
# 32  Jersey City    265549.0     Paterson     145627.0  Elizabeth     128885.0
# 43     Cranston     81274.0      Warwick      80847.0  Pawtucket      71847.0
# 42      Bayamón    170480.0     Carolina     147661.0      Ponce     133191.0
# 23    Worcester    185877.0  Springfield     155032.0  Cambridge     118977.0
#
#               City_5  city_5_pop            X  PopDensity2020
# 9                NaN         NaN  4364.208861     4364.208861
# 32           Edison     100008.0   487.688035      487.688035
# 43  East Providence      47476.0   409.775579      409.775579
# 42           Caguas     124434.0   370.531574      370.531574
# 23           Lowell     111670.0   347.981239      347.981239
#
# [5 rows x 28 columns]

# %%
#Question2) American Samoa, Guam, Northern Mariana Islands, US Virgin Islands

# %%
facts[(facts['Area_water']>facts['Area_land'])]
# Out:
#                              State  Area_tot  Area_land  Area_water  Pop_2020  \
# 2                  American Samoa       1505        198        1307   49437.0
# 12                           Guam       1478        543         935     168.4
# 37       Northern Mariana Islands       5117        472        4644      51.0
# 48   United States Virgin Islands       1898        348        1550  106235.0
#
#     Pop_2010 Rep_seats           State_bird                State_flower  \
# 2      55519       1*                  None            Paogo (Ulafala)
# 12    159358       1*   Guam rail (ko'ko')   Bougainvillea spectabilis
# 37     53883       1*   Mariana fruit-dove                 Flores mayo
# 48    106405       1*      California gull                Yellow Elder
#
#                     State_motto  ... city_2_pop       City_3  city_3_pop  \
# 2        Samoa, Muamua Le Atua   ...     3955.0   Pago Pago       3656.0
# 12  Where America's Day Begins   ...    20539.0    Tamuning      19685.0
# 37                          NaN  ...     3136.0       Rota2       2527.0
# 48     United in Pride and Hope  ...    13003.0  Northside3      10049.0
#
#                 City_4 city_4_pop          City_5 city_5_pop           X  \
# 2            'Ili'ili      3195.0      Pava'ia'i      2450.0  249.681818
# 12           Mangilao     15191.0      Barrigada      8875.0    0.310129
# 37  Northern Islands2         0.0             NaN        NaN    0.108051
# 48          East End3      5128.0  Southcentral3      3277.0  305.272989
#
#    PopDensity2020  Population Increase
# 2      249.681818              -6082.0
# 12       0.310129            -159189.6
# 37       0.108051             -53832.0
# 48     305.272989               -170.0
#
# [4 rows x 29 columns]

# %%
#Question3  Texas, Florida, California, Georgia, Washington

# %%
facts['Population Increase']=facts['Pop_2020']-facts['Pop_2010']
facts.sort_values(by='Population Increase',ascending=False).head(5)
# Out:
#            State  Area_tot  Area_land  Area_water    Pop_2020  Pop_2010  \
# 47        Texas     695662     676587       19075  29145505.0  25145561
# 10      Florida     170312     138887       31424  21538187.0  18801310
# 5    California     423967     403466       20501  39538223.0  37253956
# 11      Georgia     153910     148959        4951  10711908.0   9687653
# 52   Washington     184661     172119       12542   7705281.0   6724540
#
#    Rep_seats                              State_bird         State_flower  \
# 47        38                   Northern mockingbird       Bluebonnet sp.
# 10        28                   Northern mockingbird        Orange blossom
# 5         52                       California quail     California poppy
# 11        14                         Brown thrasher         Cherokee rose
# 52        10  Willow goldfinch (American goldfinch)   Coast rhododendron
#
#                      State_motto  ...        City_2 city_2_pop     City_3  \
# 47                   Friendship   ...  San Antonio   1532233.0    Dallas
# 10              In God we trust   ...        Miami    476329.0     Tampa
# 5                        Eureka   ...    San Diego   1425976.0  San Jose
# 11  Wisdom, Justice, Moderation   ...      Augusta    196939.0  Columbus
# 52                        Al-ki   ...      Spokane    219190.0    Tacoma
#
#     city_3_pop          City_4  city_4_pop           City_5  city_5_pop  \
# 47   1356785.0         Austin     993649.0      Fort Worth     902938.0
# 10    401189.0        Orlando     289191.0  St. Petersburg     265098.0
# 5    1030119.0  San Francisco     884198.0          Fresno     530093.0
# 11    194160.0          Macon     153095.0        Savannah     147181.0
# 52    216279.0      Vancouver     183012.0        Bellevue     147599.0
#
#        p_drop  Population Increase
# 47  61.172340            3999944.0
# 10  70.802674            2736877.0
# 5   86.740992            2284267.0
# 11  70.827924            1024255.0
# 52  80.439245             980741.0
#
# [5 rows x 28 columns]

# %%
#Question4

# %%
birds = facts[['Pop_2020','State_bird']].groupby(by='State_bird').sum()
birds.sort_values(by='Pop_2020',ascending=False)
# Out:
#                                            Pop_2020
# State_bird
# Northern mockingbird                     63567335.0
# Northern cardinal                        56767817.0
# California quail                         39538223.0
# Eastern bluebird                         26356162.0
# American robin                           19576993.0
# Ruffed Grouse                            13002700.0
# Eastern goldfinch (American goldfinch)   12479363.0
# Western meadowlark                       10999959.0
# Brown thrasher                           10711908.0
# Willow goldfinch (American goldfinch)     7705281.0
# Cactus wren                               7151502.0
# Black-capped chickadee                    7029917.0
# Baltimore oriole                          6177224.0
# Lark bunting                              5773714.0
# Common loon                               5706494.0
# Carolina wren                             5118425.0
# Yellowhammer (Northern flicker)           5024279.0
# Mountain bluebird                         4943720.0
# Brown pelican                             4657757.0
# Scissor-tailed flycatcher                 3959353.0
# None                                      3285874.0
# Hermit thrush                             3271616.0
# Greater roadrunner                        2117522.0
# Hawaiian goose (Nēnē)                     1455271.0
# Purple finch                              1377529.0
# Chickadee                                 1362359.0
# Rhode Island Red                          1097379.0
# Delaware Blue Hen                          989948.0
# Ring-necked pheasant                       886667.0
# Willow ptarmigan                           733391.0
# Wood thrush                                689545.0
# Bananaquit                                 643077.0
# Western meadowlark                         576851.0
# California gull                            106235.0
# None                                        49437.0
# Guam rail (ko'ko')                            168.4
# Mariana fruit-dove                             51.0

# %%
birds = facts[['Area_land','State_bird']].groupby(by='State_bird').sum()
birds.sort_values(by='Area_land',ascending=False)
# Out:
#                                          Area_land
# State_bird
# Willow ptarmigan                           1477953
# Western meadowlark                         1215009
# Northern mockingbird                       1178574
# Northern cardinal                           735138
# Mountain bluebird                           498377
# California quail                            403466
# Greater roadrunner                          314161
# Eastern bluebird                            300097
# American robin                              299245
# Cactus wren                                 294207
# Lark bunting                                268431
# Western meadowlark                          251470
# Hermit thrush                               212818
# Common loon                                 206232
# Ring-necked pheasant                        196350
# Scissor-tailed flycatcher                   177660
# Willow goldfinch (American goldfinch)       172119
# Eastern goldfinch (American goldfinch)      163716
# Brown thrasher                              148959
# Yellowhammer (Northern flicker)             131171
# Ruffed Grouse                               115883
# Brown pelican                               111898
# Chickadee                                    79883
# Carolina wren                                77857
# Baltimore oriole                             25142
# Bananaquit                                   23871
# Purple finch                                 23187
# Black-capped chickadee                       20202
# Hawaiian goose (Nēnē)                        16635
# None                                          8868
# Delaware Blue Hen                             5047
# Rhode Island Red                              2678
# Guam rail (ko'ko')                             543
# Mariana fruit-dove                             472
# California gull                                348
# None                                           198
# Wood thrush                                    158

# %%
#Question 5 17 (not including DC)

# %%
facts[(facts['City_1']==facts['Capital'])].groupby(by='State').sum()
# Out:
#                         Area_tot  Area_land  Area_water    Pop_2020  Pop_2010  \
# State
#  Arizona                  295234     294207        1026   7151502.0   6392017
#  Arkansas                 137732     134771        2961   3011524.0   2915918
#  Colorado                 269601     268431        1170   5773714.0   5029196
#  District of Columbia        177        158          19    689545.0    601723
#  Georgia                  153910     148959        4951  10711908.0   9687653
#  Idaho                    216443     214045        2398   1839106.0   1567582
#  Indiana                   94326      92789        1537   6785528.0   6483802
#  Iowa                     145746     144669        1077   3190369.0   3046355
#  Massachusetts             27336      20202        7134   7029917.0   6547629
#  Mississippi              125438     121531        3907   2961279.0   2967297
#  Ohio                     116098     105829       10269  11799448.0  11536504
#  Oklahoma                 181037     177660        3377   3959353.0   3751351
#  Rhode Island               4001       2678        1324   1097379.0   1052567
#  Tennessee                109153     106798        2355   6910840.0   6346105
#  Utah                     219882     212818        7064   3271616.0   2763885
#  West Virginia             62756      62259         497   1793716.0   1852994
#  Wyoming                  253335     251470        1864    576851.0    563626
#
#                         GDP_2020  GDP_2019  Capital_pop  city_1_pop  \
# State
#  Arizona                372461.0  370119.1      1680992     1660272
#  Arkansas               129073.9  130954.1       197312      197881
#  Colorado               390098.7  392986.0       727211      719238
#  District of Columbia   143532.7  143389.3       702455      702455
#  Georgia                619240.0  625713.6       506811      504527
#  Idaho                   84032.2   83665.5       228959      228790
#  Indiana                372636.7  379684.1       876384      867125
#  Iowa                   192710.2  194658.1       214237      216853
#  Massachusetts          584039.0  596593.1       692600      699927
#  Mississippi            114200.6  115971.3       160628      164422
#  Ohio                   675037.3  695361.6       898553      895477
#  Oklahoma               186581.4  202036.1       655057      649021
#  Rhode Island            60224.7   61883.8       179883      179335
#  Tennessee              364485.9  376582.4       670820      681928
#  Utah                   194985.8  192519.2       200567      200591
#  West Virginia           73709.2   78863.9        46536       47215
#  Wyoming                 36241.5   40420.1        64235       63957
#
#                         city_2_pop  city_3_pop  city_4_pop  city_5_pop  \
# State
#  Arizona                  545975.0    508958.0    257165.0    255310.0
#  Arkansas                  87845.0     86751.0     81029.0     76990.0
#  Colorado                 483829.0    374114.0    167830.0    156798.0
#  District of Columbia          0.0         0.0         0.0         0.0
#  Georgia                  196939.0    194160.0    153095.0    147181.0
#  Idaho                    106894.0     96252.0     63398.0     56541.0
#  Indiana                  267633.0    117963.0    103290.0     99329.0
#  Iowa                     133174.0    102085.0     82396.0     76290.0
#  Massachusetts            185877.0    155032.0    118977.0    111670.0
#  Mississippi               71870.0     54944.0     45968.0     45951.0
#  Ohio                     382817.0    302605.0    273782.0    198006.0
#  Oklahoma                 400669.0    123471.0    109471.0     93127.0
#  Rhode Island              81274.0     80847.0     71847.0     47476.0
#  Tennessee                650618.0    187500.0    180557.0    163648.0
#  Utah                     136401.0    118178.0    116046.0     97521.0
#  West Virginia             46048.0     30955.0     29675.0     26771.0
#  Wyoming                   57461.0     32473.0     31903.0     23082.0
#
#                                   X  PopDensity2020
# State
#  Arizona                  24.307722       24.307722
#  Arkansas                 22.345490       22.345490
#  Colorado                 21.509118       21.509118
#  District of Columbia   4364.208861     4364.208861
#  Georgia                  71.911788       71.911788
#  Idaho                     8.592147        8.592147
#  Indiana                  73.128582       73.128582
#  Iowa                     22.052886       22.052886
#  Massachusetts           347.981239      347.981239
#  Mississippi              24.366450       24.366450
#  Ohio                    111.495412      111.495412
#  Oklahoma                 22.286125       22.286125
#  Rhode Island            409.775579      409.775579
#  Tennessee                64.709451       64.709451
#  Utah                     15.372835       15.372835
#  West Virginia            28.810549       28.810549
#  Wyoming                   2.293916        2.293916

# %%
len(facts[facts['Capital']==facts['City_1']][['State','Capital']])
# Out:
# 17

# %%
# Question 6

# %%
facts['p_drop'] = 100*(facts['city_1_pop']-facts['city_5_pop'])/facts['city_1_pop']

# %%
facts[['State','City_1','city_1_pop','City_5','city_5_pop','p_drop']].sort_values(by='p_drop',ascending=False).head(1)
# Out:
#          State          City_1  city_1_pop     City_5  city_5_pop     p_drop
# 34   New York   New York City      8879928  Syracuse     142749.0  98.392453

# %% [markdown]
# >Using the "state_dates.tsv" data, answer the remaining questions. You will need to merge the two data sets together:
#
# >7) Of the states that joined the United States before 1790, what is the most common state flower?
# >8) Which has the larger population density, the most dense US Territory or the least dense state?
# >9) Make a graph that plots the populations of the largest city in each entity in the order in which they joined the US. Make the bars black
# >10) Make two additional graphs like the one above but one for land area (green bars) and one for water area (blue bars)

# %% [markdown]
# Hint: `pd.read_csv('../data/state_dates.tsv',delimiter="\t")`
#
# Hint: You likely want to convert the Date column to datetime. You might have to correct errors in the data as well.
#
# Hint: `states['Date']<pd.datetime(1790,1,1)`
#
# Hint: `pd.merge(****,****,left_on='USPS_code',right_on='Abbreviation',how='outer')`

# %%
# Sample code to help with the plots

#import matplotlib as plt
#%config InlineBackend.figure_format ='retina' #This makes your plot clearer


#plot = *your df by date*[[*column*,'Abbreviation']].plot(kind='bar',figsize=(10,4))
#plot.set_xticklabels(*your df by date*['Abbreviation']);

# %%
pd.read_csv('../data/state_dates.tsv',delimiter="\t")
# Out:
#                             Name               Date            Status  \
# 0                       Alabama   December 14, 1819             State
# 1                        Alaska     January 3, 1959             State
# 2                 American Samoa     April 17, 1900         Territory
# 3                       Arizona   February 14, 1912             State
# 4                      Arkansas       June 15, 1836             State
# 5                    California   September 9, 1850             State
# 6                      Colorado      August 1, 1876             State
# 7                   Connecticut     January 9, 1788             State
# 8                      Delaware    December 7, 1787             State
# 9           District of Columbia  February 21, 1871  Federal District
# 10                      Florida       March 3, 1845             State
# 11                      Georgia     January 2, 1788             State
# 12                          Guam     April 11, 1899         Territory
# 13                       Hawaii     August 21, 1959             State
# 14                        Idaho        July 3, 1890             State
# 15                     Illinois    December 3, 1818             State
# 16                      Indiana   December 11, 1816             State
# 17                         Iowa   December 28, 1846             State
# 18                       Kansas    January 29, 1861             State
# 19                     Kentucky        June 1, 1792             State
# 20                    Louisiana      April 30, 1812             State
# 21                        Maine      March 15, 1820             State
# 22                     Maryland      April 28, 1788             State
# 23                Massachusetts    February 6, 1788             State
# 24                     Michigan    January 26, 1837             State
# 25                    Minnesota        May 11, 1858             State
# 26                  Mississippi   December 10, 1817             State
# 27                     Missouri     August 10, 1821             State
# 28                      Montana    November 8, 1889             State
# 29                     Nebraska       March 1, 1867             State
# 30                       Nevada    October 31, 1864             State
# 31                New Hampshire       June 21, 1788             State
# 32                   New Jersey   December 18, 1787             State
# 33                   New Mexico     January 6, 1912             State
# 34                     New York       July 26, 1788             State
# 35               North Carolina   November 21, 1789             State
# 36                 North Dakota    November 2, 1889             State
# 37      Northern Mariana Islands   November 4, 1986         Territory
# 38                         Ohio       March 1, 1803             State
# 39                     Oklahoma   November 16, 1907             State
# 40                       Oregon   February 14, 1859             State
# 41                 Pennsylvania   December 12, 1787             State
# 42                   Puerto Rico     April 11, 1899         Territory
# 43                 Rhode Island        May 29, 1790             State
# 44               South Carolina        May 23, 1788             State
# 45                 South Dakota    November 2, 1889             State
# 46                    Tennessee        June 1, 1796             State
# 47                        Texas   December 29, 1845             State
# 48  United States Virgin Islands     March 31, 1917         Territory
# 49                         Utah     January 4, 1896             State
# 50                      Vermont       March 4, 1791             State
# 51                     Virginia       June 25, 1788             State
# 52                   Washington   November 11, 1889             State
# 53                West Virginia       June 20, 1863             State
# 54                    Wisconsin        May 29, 1848             State
# 55                      Wyoming       July 10, 1890             State
#
#    Abbreviation
# 0           AL
# 1           AK
# 2            AS
# 3           AZ
# 4           AR
# 5           CA
# 6           CO
# 7           CT
# 8           DE
# 9           DC
# 10          FL
# 11          GA
# 12           GU
# 13          HI
# 14          ID
# 15          IL
# 16          IN
# 17          IA
# 18          KS
# 19          KY
# 20          LA
# 21          ME
# 22          MD
# 23          MA
# 24          MI
# 25          MN
# 26          MS
# 27          MO
# 28          MT
# 29          NE
# 30          NV
# 31          NH
# 32          NJ
# 33          NM
# 34          NY
# 35          NC
# 36          ND
# 37           MP
# 38          OH
# 39          OK
# 40          OR
# 41          PA
# 42           PR
# 43          RI
# 44          SC
# 45          SD
# 46          TN
# 47          TX
# 48           VI
# 49          UT
# 50          VT
# 51          VA
# 52          WA
# 53          WV
# 54          WI
# 55          WY

# %%
#Question 7

# %%
dates = pd.read_csv('../data/state_dates.tsv',delimiter="\t")
dates.head()
# Out:
#              Name               Date     Status Abbreviation
# 0        Alabama   December 14, 1819      State          AL
# 1         Alaska     January 3, 1959      State          AK
# 2  American Samoa     April 17, 1900  Territory           AS
# 3        Arizona   February 14, 1912      State          AZ
# 4       Arkansas       June 15, 1836      State          AR

# %%
facts=facts.sort_values(by='State')

# %%
states=pd.merge(facts,dates,left_on='USPS_code',right_on='Abbreviation',how='outer')
states.head()
# Out:
#               State  Area_tot  Area_land  Area_water   Pop_2020  Pop_2010  \
# 0          Alabama     135767     131171        4597  5024279.0   4779736
# 1           Alaska    1723337    1477953      245384   733391.0    710231
# 2   American Samoa       1505        198        1307    49437.0     55519
# 3          Arizona     295234     294207        1026  7151502.0   6392017
# 4         Arkansas     137732     134771        2961  3011524.0   2915918
#
#   Rep_seats                        State_bird             State_flower  \
# 0         7  Yellowhammer (Northern flicker)                  Camellia
# 1         1                 Willow ptarmigan            Forget-me-not
# 2       1*                               None         Paogo (Ulafala)
# 3         9                      Cactus wren   Saguaro cactus blossom
# 4         4             Northern mockingbird            Apple blossom
#
#                       State_motto  ... city_3_pop       City_4  city_4_pop  \
# 0  Audemus jura nostra defendere   ...   198956.0      Mobile     189572.0
# 1            North to the Future   ...    31516.0     Wasilla      10529.0
# 2          Samoa, Muamua Le Atua   ...     3656.0    'Ili'ili       3195.0
# 3                     Ditat Deus   ...   508958.0    Chandler     257165.0
# 4                 Regnat populus   ...    86751.0  Springdale      81029.0
#
#         City_5 city_5_pop     p_drop            Name               Date  \
# 0  Tuscaloosa    101113.0  51.603902        Alabama   December 14, 1819
# 1       Sitka      8647.0  97.034006         Alaska     January 3, 1959
# 2   Pava'ia'i      2450.0  69.162996  American Samoa     April 17, 1900
# 3  Scottsdale    255310.0  84.622399        Arizona   February 14, 1912
# 4   Jonesboro     76990.0  61.092778       Arkansas       June 15, 1836
#
#       Status  Abbreviation
# 0      State           AL
# 1      State           AK
# 2  Territory            AS
# 3      State           AZ
# 4      State           AR
#
# [5 rows x 31 columns]

# %%
states['Date']=pd.to_datetime(states['Date'])
states[states['Date']<pd.datetime(1790,1,1)]['State_flower'].value_counts()
# Out:
# <ipython-input-96-05d854f77349>:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   states[states['Date']<pd.datetime(1790,1,1)]['State_flower'].value_counts()
# Mountain laurel      2
# Flowering dogwood    1
# Mayflower            1
# Black-eyed susan     1
# Rose                 1
# American dogwood     1
# Yellow jessamine     1
# Purple lilac         1
# Cherokee rose        1
# Violet               1
# Peach blossom        1
# Name: State_flower, dtype: int64

# %%
#Question 8

# %%
ter = states[states['Status']=='Territory']

# %%
sta = states[states['Status']=='State']

# %%
ter['PopDensity2020'] = ter['Pop_2020']/ter['Area_land']
ter = ter.sort_values(by='PopDensity2020',ascending=False)
ter[['State','PopDensity2020']].head(1)
# Out:
# <ipython-input-101-4ae63d601930>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ter['PopDensity2020'] = ter['Pop_2020']/ter['Area_land']
#             State  PopDensity2020
# 42   Puerto Rico       370.531574

# %%
sta['PopDensity2020'] = sta['Pop_2020']/sta['Area_land']
sta = sta.sort_values(by='PopDensity2020',ascending=True)
sta[['State','PopDensity2020']].head(1)
# Out:
#       State  PopDensity2020
# 1   Alaska         0.496221

# %%
# Question 9

# %%
statebydate = states.sort_values(by='Date')

# %%
import matplotlib as plt
# %config InlineBackend.figure_format = 'retina'

plot = statebydate[['city_1_pop','Abbreviation']].plot(kind='bar',figsize=(10,4),color='red')
plot.set_xticklabels(statebydate['Abbreviation']);

# %%
#Question 10

# %%
import matplotlib as plt
# %config InlineBackend.figure_format = 'retina'

plot = statebydate[['Area_land','Abbreviation']].plot(kind='bar',figsize=(10,4),color='blue')
plot.set_xticklabels(statebydate['Abbreviation']);

# %%
import matplotlib as plt
# %config InlineBackend.figure_format = 'retina'

plot = statebydate[['Area_water','Abbreviation']].plot(kind='bar',figsize=(10,4),color='green')
plot.set_xticklabels(statebydate['Abbreviation']);
