# %% [markdown]
# # Data Visualization

# %% [markdown]
# Select a dataset we have used in class (or outside of class).
#
# Generate a plot that you feel visualizes the data is an interesting way. Your plot should have the following elements:
#
# >1) Title
# >2) Legend
# >3) Axes or other Labels
# >4) Color
# >5) 1 sentence description of what your plot shows
# >6) Brief description of why you chose to make the plot the way you did.
#
# You may use pandas, matplotlib, or seaborn.

# %%
import pandas as pd
import matplotlib as plt

# %matplotlib inline
# %config InlineBackend.figure_format ='retina'

# %%
# %matplotlib inline

# %%
p1 = data[['GDP_2020','Pop_2020','Capital_pop','city_1_pop']]

# %%
p1.plot.scatter(x='GDP_2020', y='Pop_2020', label='Productivity Per State')
# Out:
# <AxesSubplot:xlabel='GDP_2020', ylabel='Pop_2020'>

# %%
ax = data.plot.scatter(x='Pop_2020', y="GDP_2020", label="Productivity")
data.plot.scatter(x='Pop_2020', y='GDP_2020', label="Productivity", ax=ax)
# Out:
# <AxesSubplot:xlabel='Pop_2020', ylabel='GDP_2020'>

# %%
ax = data.plot.scatter(x='GDP_2020', y="Pop_2020")
data.plot.scatter(x='GDP_2020', y='Pop_2020', label="Productivity Per State", ax=ax, xlabel="State GDP", ylabel="Population of Each State", title='GDP per State - 2020', grid=True)
# Out:
# <AxesSubplot:title={'center':'GDP per State - 2020'}, xlabel='State GDP', ylabel='Population of Each State'>

# %%
ax = data.plot.scatter(x='Pop_2020', y="GDP_2020")
plt = data.plot.scatter(x='Pop_2020', y='GDP_2020', color = 'red', label="Per Capita GDP", ax=ax, xlabel="Population of Each State", ylabel="State GDP", title='Pop vs. GDP 2020', grid=True)

# %%
plt.figure.savefig('Pop vs GDP 2020.pdf')

# %%
# My plot shows the trend of how the population affects the economy of each state. 


# I chose to make the plot the way I did because I wanted to show that the slow was for the most part similar so we can easily predict based on the population of a state in the US what there expected GDP should be. The grid helps with that by showing the trend. Also, I made it this way so that we can possibly predict in the future based on this years data, the GDP of each state based on the population.
